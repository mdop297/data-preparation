# %%
cd /app
# Out:
# /app
# /home/nhatminh/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pwd
# Out:
# /app

# %%
import pandas as pd

# %%
train_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/train.csv")
test_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test.csv")
test_labels_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test_labels.csv")

# %%
print(f"{train_df.shape=}")
print(f"{test_df.shape=}")
print(f"{test_labels_df.shape=}")
# Out:
# train_df.shape=(159571, 8)
# test_df.shape=(153164, 2)
# test_labels_df.shape=(153164, 7)

# %%
train_df.sample(n=20)
# Out:
#                       id                                       comment_text  \
# 24108   3fb561505dfbfc87  "::::::""you have outright lied in edit histor...
# 116751  70239bbd3ff54430  What is wrong with my edit, besides the fact t...
# 132885  c6f245cc49db9a28  Excuse Me!?!\nDon't be deleteing my stuff llik...
# 145402  1c11598310fe9830  " As someone said in the Vallage SPAR shop - "...
# 44596   772b0c2fbd75dcbf  The charges are insane, making valid criticism...
# 24667   413932b1fb528c6a  EU colors \n\nDear Bastin, thanks for cleaning...
# 115838  6b6f8431c1d5c311  sorry\n\nIm really really sick of you bunch of...
# 147741  40f6cce4f4a93776  "\n I agree that the addition is unnecessary. ...
# 35833   5fbd8b7446fda173  It's not hime, but it's definately an allusion...
# 97898   0bbb5be146b3af65  Sorry for any personal attacks, I'm just confu...
# 115607  6a50326e8c34ef1c  People who  might still follow it, people who ...
# 148996  5558ddb4906beede  ", 19 March 2008 (UTC)\n\nOk, well i have thro...
# 13591   23e366f43f891f16  "\n\n Further on Amdo \n\nHi, I appreciate you...
# 15638   294a4db72d54996b  New York City regulation \n\nRegarding the rem...
# 39988   6aba19084ade8f35                 Fuck you London. You piece of shit
# 47574   7f1aabaf2d8bc0e3        YOU DELETED KORY SHERMAN NOW YOU HAVE AIDS!
# 17884   2f37ea3bc5f219c3  You did it again ! Why did you change the arti...
# 59644   9fb0432c0e520474                           Please wikify this page.
# 39233   68b1ca441504379e  ":If I may throw my two cents into the hat, I ...
# 76469   ccb9067bc1111b84    Show me how you do that (redirecting the page)?
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 24108       0             0        0       0       0              0
# 116751      0             0        0       0       0              0
# 132885      1             0        1       0       0              0
# 145402      0             0        0       0       0              0
# 44596       0             0        0       0       0              0
# 24667       0             0        0       0       0              0
# 115838      1             0        0       0       0              0
# 147741      0             0        0       0       0              0
# 35833       0             0        0       0       0              0
# 97898       0             0        0       0       0              0
# 115607      0             0        0       0       0              0
# 148996      0             0        0       0       0              0
# 13591       0             0        0       0       0              0
# 15638       0             0        0       0       0              0
# 39988       1             0        1       0       1              0
# 47574       1             0        0       0       0              0
# 17884       0             0        0       0       0              0
# 59644       0             0        0       0       0              0
# 39233       0             0        0       0       0              0
# 76469       0             0        0       0       0              0

# %%
train_df["identity_hate"].unique()
# Out:
# array([0, 1])

# %%
test_df.head(10)
# Out:
#                  id                                       comment_text
# 0  00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1  0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2  00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3  00017563c3f7919a  :If you have a look back at the source, the in...
# 4  00017695ad8997eb          I don't anonymously edit articles at all.
# 5  0001ea8717f6de06  Thank you for understanding. I think very high...
# 6  00024115d4cbde0f  Please do not add nonsense to Wikipedia. Such ...
# 7  000247e83dcc1211                   :Dear god this site is horrible.
# 8  00025358d4737918  " \n Only a fool can believe in such numbers. ...
# 9  00026d1092fe71cc  == Double Redirects == \n\n When fixing double...

# %%
test_labels_df.head(10)
# Out:
#                  id  toxic  severe_toxic  obscene  threat  insult  \
# 0  00001cee341fdb12     -1            -1       -1      -1      -1
# 1  0000247867823ef7     -1            -1       -1      -1      -1
# 2  00013b17ad220c46     -1            -1       -1      -1      -1
# 3  00017563c3f7919a     -1            -1       -1      -1      -1
# 4  00017695ad8997eb     -1            -1       -1      -1      -1
# 5  0001ea8717f6de06      0             0        0       0       0
# 6  00024115d4cbde0f     -1            -1       -1      -1      -1
# 7  000247e83dcc1211      0             0        0       0       0
# 8  00025358d4737918     -1            -1       -1      -1      -1
# 9  00026d1092fe71cc     -1            -1       -1      -1      -1
#
#    identity_hate
# 0             -1
# 1             -1
# 2             -1
# 3             -1
# 4             -1
# 5              0
# 6             -1
# 7              0
# 8             -1
# 9             -1

# %%
test_labels_df["toxic"].unique()
# Out:
# array([-1,  0,  1])

# %%
test_labels_df[test_labels_df["toxic"] != -1].shape
# Out:
# (63978, 7)

# %%
test_labels_df[
    (test_labels_df["toxic"] != -1) &
    (test_labels_df["severe_toxic"] != -1) &
    (test_labels_df["obscene"] != -1) &
    (test_labels_df["threat"] != -1) &
    (test_labels_df["insult"] != -1) &
    (test_labels_df["identity_hate"] != -1)
].shape
# Out:
# (63978, 7)
