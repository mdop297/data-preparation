# %%
cd /app
# Out:
# /app
# /home/nhatminh/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/raw/twitter/cyberbullying_tweets.csv")

# %%
print(f"{df.shape=}")
# Out:
# df.shape=(47692, 2)

# %%
(len(df) - (len(df) * 0.2)) * 0.25
# Out:
# 9538.4

# %%
df.sample(n=50)
# Out:
#                                               tweet_text   cyberbullying_type
# 9623   female is usually used interchangeably with "b...               gender
# 12917  So you can be offended by Gay jokes, but a con...               gender
# 32553  Joe Rogan Episode #5434 Your Bully in High School                  age
# 45529  @JR4_07 @TweakMonster dumb fucks....go suck ya...            ethnicity
# 22292  Actually, to the (what you wrongly refer to as...             religion
# 19442  you are the same as the idiots chanting all li...             religion
# 34709  ONE DIRECTION ARE BULLIES HIGH SCHOOL FUCKING ...                  age
# 30038  RT @ToufiqueKhalidi: Those who are even discus...  other_cyberbullying
# 29816        The fucker Darwin has a lot to answer for!!  other_cyberbullying
# 39159  A girl I went to high school with, but the bes...                  age
# 17292  Yes plz highlight the hindu extremist,which is...             religion
# 1546   @Najween__ No, microbrain, the Pesh are not us...    not_cyberbullying
# 1854   @obsurfer84 Here is the story of the Ghatafan....    not_cyberbullying
# 33316  When Tom is scrunched on the #football field b...                  age
# 16183  Idiot lady is just propagating lies.. Where ar...             religion
# 4095   Push your cock inside me,i am a bad police,pun...    not_cyberbullying
# 6532   @alaan_wtf ese tambien lo deberia de estar vie...    not_cyberbullying
# 36170  The only acceptable time to promote St. Ives A...                  age
# 4242   I planned on getting stuff done today, but end...    not_cyberbullying
# 28529  @emily_esque I would love that. would you mind...  other_cyberbullying
# 29367                 Sometimes I feel like Olivia Pope.  other_cyberbullying
# 40493  This white hispanic called me a negro using a ...            ethnicity
# 6143   @_DirtyTruths I don't follow any religion, mic...    not_cyberbullying
# 20313  He Knew He Was Going To Have Me Tell You The T...             religion
# 10596  @mark93tuna yeah tbh im not /THAT/ bothered ab...               gender
# 18633  Name one other non-Muslim majority nation whic...             religion
# 6259   @halalfam @biebervalue @greenlinerzjm All the ...    not_cyberbullying
# 41335  RT @realdealsky11: Just cuz my money keep runn...            ethnicity
# 40421  Dumb nigger — fuck you joee http://ask.fm/a/4j...            ethnicity
# 1106   @owrangle Instant replays of people boiling an...    not_cyberbullying
# 9154   But these girls Its just rape, trans, gay joke...               gender
# 9637   RT @CorinnaSladey: Kat is busy warming up her ...               gender
# 25025  Feminazi? Right. Because wanting your #gender ...  other_cyberbullying
# 30901  it's gonna a girls round on #mkr this week but...  other_cyberbullying
# 8307   @rvikander What's he fighting for? Gays feelin...               gender
# 8626                @Alan_Wickham http://t.co/ztGVbCaClu               gender
# 21943  @Iz_abdul By now no one buys that "few individ...             religion
# 487    Can't quite shake the feeling that #MKR is a t...    not_cyberbullying
# 36450                        high school fucking bullies                  age
# 9625   VIDEO: Miley Cyrus Makes Date Rape Joke at Gay...               gender
# 28496  @latimeralder @supermathskid And here's one of...  other_cyberbullying
# 1082   guess who I am: WE HATE STRATEGIC SCORING BUT ...    not_cyberbullying
# 15910  @DBAB_Holloway: Check out our 12th man. #Cowbo...               gender
# 30407  @Taurmaurils i dunno. it makes me happy. they ...  other_cyberbullying
# 17942  @scamp_faridxx And historians have actually ma...             religion
# 10930  It you’re a “liberal” going to the mat to defe...               gender
# 22811  Why are you talking about fighting with your i...             religion
# 12974  Why punish someone for their past? I agree rap...               gender
# 28452                             http://t.co/daznQZR8Te  other_cyberbullying
# 11832  not that it's any better, but the actual joke ...               gender

# %%
df["cyberbullying_type"].unique()
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)
